# %% [markdown]
# <a href="https://colab.research.google.com/github/anacarmona1/HDS-5210-Ana/blob/main/week13_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Check in your data file along with this exercise. Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
import pandas as pd
import matplotlib.pyplot as plt
quality = pd.read_csv("qualityofcare.csv")
quality.head()
# Out:
#   State      HBIPS-2 Measure Description  S HBIPS-2 Overall Rate Per 1000  \
# 0    AK  Hours of physical-restraint use                             0.18
# 1    AL  Hours of physical-restraint use                             0.16
# 2    AR  Hours of physical-restraint use                             0.10
# 3    AZ  Hours of physical-restraint use                             0.36
# 4    CA  Hours of physical-restraint use                             0.53
#
#    S HBIPS-2 Overall Num  S HBIPS-2 Overall Den HBIPS-3 Measure Description  \
# 0                 208.85                  47204      Hours of seclusion use
# 1                1356.32                 355259      Hours of seclusion use
# 2                 722.26                 301370      Hours of seclusion use
# 3                5921.42                 689090      Hours of seclusion use
# 4               24678.81                1957115      Hours of seclusion use
#
#    S HBIPS-3 Overall Rate Per 1000  S HBIPS-3 Overall Num  \
# ...

# %%
mentalhealth = pd.read_json("mental_health.json")
mentalhealth.head()
# Out:
#         state  MentalHealthStatisticsRatesOfMentalIllness  \
# 0     Alabama                                       21.24
# 1      Alaska                                       22.20
# 2     Arizona                                       23.89
# 3    Arkansas                                       22.61
# 4  California                                       20.49
#
#    MentalHealthStatisticsAdultsWithAnxietyOrDepresion  \
# 0                                               38.2
# 1                                               31.6
# 2                                               33.2
# 3                                               30.6
# 4                                               32.6
#
#    MentalHealthStatisticsAdultsWithSevereMentalIllness  \
# 0                                                5.6
# 1                                                5.9
# 2                                                5.6
# 3                                                5.5
# ...

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
mentalhealth = pd.read_json("mental_health.json")
unique_values = mentalhealth.drop(columns=['state']).nunique()
most_diverse = unique_values.idxmax()
most_diverse_count = unique_values.max()
print(unique_values)
# Out:
# MentalHealthStatisticsRatesOfMentalIllness                      50
# MentalHealthStatisticsAdultsWithAnxietyOrDepresion              40
# MentalHealthStatisticsAdultsWithSevereMentalIllness             20
# MentalHealthStatisticsOverallMentalHealthStandingYouthAdults    50
# dtype: int64

# %%
print(most_diverse)
# Out:
# MentalHealthStatisticsRatesOfMentalIllness

# %%
print(most_diverse_count)
# Out:
# 50

# %%
quality = pd.read_csv("qualityofcare.csv")
unique_values = quality.drop(columns=['State']).nunique()
most_diverse = unique_values.idxmax()
most_diverse_count = unique_values.max()
print(unique_values)
# Out:
# HBIPS-2 Measure Description                1
# S HBIPS-2 Overall Rate Per 1000           38
# S HBIPS-2 Overall Num                     52
# S HBIPS-2 Overall Den                     52
# HBIPS-3 Measure Description                1
# S HBIPS-3 Overall Rate Per 1000           35
# S HBIPS-3 Overall Num                     52
# S HBIPS-3 Overall Den                     52
# HBIPS-5 Measure Description                1
# S HBIPS-5 %                               38
# SMD Measure Description                    1
# S SMD %                                   29
# SUB-2/-2a Measure Description              1
# S SUB-2 %                                 34
# S SUB-2a %                                31
# SUB-3/-3a Measure Description              1
# S SUB-3 %                                 32
# S SUB-3a %                                30
# TOB-2/-2a Measure Desc                     1
# S TOB-2 %                                 32
# S TOB-2a %                                37
# ...

# %%
print(most_diverse)
# Out:
# S HBIPS-2 Overall Num

# %%
print(most_diverse_count)
# Out:
# 52

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
mentalhealth = pd.read_json("mental_health.json", encoding="latin1")
constant_columns = mentalhealth.columns[mentalhealth.nunique() == 1]
if not constant_columns.empty:
    print("Columns where all rows have the same value:")
    print(constant_columns.tolist())
else:
    print("No columns have the same value for all rows.")
# Out:
# No columns have the same value for all rows.

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
quality['S HBIPS-2 Overall Num'].hist()
# Out:
# <Axes: >

# %%
mentalhealth['MentalHealthStatisticsRatesOfMentalIllness'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
mentalhealth.describe()
# Out:
#        MentalHealthStatisticsRatesOfMentalIllness  \
# count                                   51.000000
# mean                                    21.901716
# std                                      2.600654
# min                                     17.490000
# 25%                                     20.515000
# 50%                                     21.390000
# 75%                                     23.530000
# max                                     29.680000
#
#        MentalHealthStatisticsAdultsWithAnxietyOrDepresion  \
# count                                          51.000000
# mean                                           31.449822
# std                                             3.366810
# min                                            23.900000
# 25%                                            30.150000
# 50%                                            32.100000
# 75%                                            33.000000
# ...

# %%
mentalhealth.plot.scatter(x='MentalHealthStatisticsRatesOfMentalIllness', y='MentalHealthStatisticsOverallMentalHealthStandingYouthAdults')
# Out:
# <Axes: xlabel='MentalHealthStatisticsRatesOfMentalIllness', ylabel='MentalHealthStatisticsOverallMentalHealthStandingYouthAdults'>

# %%
quality.describe()
# Out:
#        S HBIPS-2 Overall Rate Per 1000  S HBIPS-2 Overall Num  \
# count                        52.000000              52.000000
# mean                          0.408269            3704.024808
# std                           0.451406            4601.201076
# min                           0.040000              28.900000
# 25%                           0.110000             438.637500
# 50%                           0.215000            2126.725000
# 75%                           0.530000            5339.275000
# max                           1.970000           24678.810000
#
#        S HBIPS-2 Overall Den  S HBIPS-3 Overall Rate Per 1000  \
# count           5.200000e+01                        52.000000
# mean            4.755436e+05                         0.469423
# std             5.088115e+05                         0.966356
# min             1.337000e+04                         0.010000
# 25%             1.202685e+05                         0.117500
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(
    quality['S HBIPS-2 Overall Num'],
    quality['S READM-30-IPF # IPFs Worse'],
    alpha=0.7,
    color='blue',
    edgecolor='black'
)
plt.title('Hours of Physical Restraint vs. Readmission Rates', fontsize=16)
plt.xlabel('Hours of Physical Restraint (HBIPS-2)', fontsize=14)
plt.ylabel('Readmission Rates (READM-30-IPF)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
